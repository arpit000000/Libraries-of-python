# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
plt.plot([2,4,6,4])
plt.ylabel('Numbers')
plt.xlabel('Indicates')
plt.title('Myplot')
plt.show()

# %%
exp=[1,0,2,4,6,8,10]
sal=[20000,0,25000,50000,75000,100000,1400000]
#plt.plot(exp,sal)
plt.ylabel('salary')
plt.xlabel('exp')
plt.plot(sal,marker='o')
#plt.plot(exp)
plt.grid()
plt.show()

# %%
a=pd.read_excel(r"C:\\Users\Arpit\Desktop\pandas\sal1.xlsx",names=['age','workclass','fnlwgt','education','education_num','merital_status','occupation','relationship','race','gender','capital_gain','capital_loss','hours_per_week','native_country','salary'],na_values='?')
a
# Out:
#        age          workclass  fnlwgt    education  education_num
# 0       50   Self-emp-not-inc   83311    Bachelors             13  \
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             merital_status          occupation    relationship    race
# 0       Married-civ-spouse     Exec-managerial         Husband   White  \
# ...

# %%
n=np.arange(1,11)
plt.plot(n,n**2)
plt.plot(n,n**3)

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.ylabel('Square')
plt.xlabel('number')
plt.grid()
plt.show()

# %%
t=np.arange(0,5,0.2)

# %%
plt.plot(t,t**2,'b',label='2')
plt.plot(t,t**3,'g',label='3')
plt.plot(t,t**4,'r',label='2')
plt.grid()
plt.show()

# %%
import pandas as pd

data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
data.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

data.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
a=data["sepal length"]
b=data['petal length']

# %%
plt.plot(a,b)

# %%
a=sns.load_dataset('iris')
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
y=a['sepal_length']
m=a['petal_length']

# %%
plt.plot(y,':')
plt.plot(m,':')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show()

# %%
a=sns.load_dataset('flights')

# %%
a
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
x=a['year']
y=a['passengers']

# %%
plt.plot(x,y)

# %%
sns.lineplot(x='year',y='passengers',hue='month',data=a)
plt.box()
plt.grid()
plt.show()

# %%
sns.barplot(x='year',y='passengers',hue='month',data=a)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='year',y='passengers',data=a)
plt.show()

# %%
sns.pairplot(a)
plt.show()

# %%
cor=a.corr()
sns.heatmap(corr,annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 cor=a.corr()
#       2 sns.heatmap(corr,annot=True)
#
# File C:\python3.11\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\python3.11\Lib\site-packages\pandas\core\frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
sns.set(style='darkgrid')
sns.set(style='darkgrid')
sns.lineplot(x='month',y='passengers',data=a)
#sns.cubehelix_palette(as_cmap=True)
plt.show()

# %%
b=sns.load_dataset('iris')

# %%
b
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length',y='petal_length',hue='species',data=b)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.barplot(x='sepal_length',y='petal_length',hue='species',data=b)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.lineplot(x='sepal_length',y='petal_length',hue='species',data=b)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.jointplot(x='sepal_length',y='petal_length',hue='species',data=b,color='olive')

# %%
c=sns.load_dataset('diamonds')

# %%
c
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
x=c['carat']
y=c['price']

# %%
sns.distplot(y,bins=10,color='pink')
plt.show()
# Out:
# C:\Users\Arpit\AppData\Local\Temp\ipykernel_19460\2747190124.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y,bins=10,color='pink')

# %%
sns.displot(y,bins=10,color='pink')
plt.show()

# %%
c=sns.load_dataset('tips')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File C:\python3.11\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File C:\python3.11\Lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\python3.11\Lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
c
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(x='day',y='total_bill',data=c,hue='time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 sns.catplot(x='day',y='total_bill',data=c,hue='time')
#       2 plt.show()
#
# File C:\python3.11\Lib\site-packages\seaborn\categorical.py:3031, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3028 refactored_kinds = ["strip", "swarm"]
#    3029 if kind in refactored_kinds:
# -> 3031     p = _CategoricalFacetPlotter(
#    3032         data=data,
#    3033         variables=_CategoricalFacetPlotter.get_semantics(locals()),
#    3034         order=order,
#    3035         orient=orient,
#    3036         require_numeric=False,
#    3037         legend=legend,
# ...

# %%
import matplotlib as plt

# %%
plt.plot(2,0)
plt.show()

# %%
from tkinter import *

# %%
root=Tk()
root.geometry('600x600')
c=Canvas(root,bg='red',height=500,width=500)
#r=c.create_rectangle((110,110),(400,400),fill='green')
#r=c.create_rectangle((210,210),(300,300),fill='blue')
r=c.create_polygon((10,400),(250,200),(500,400),fill='blue')
r=c.create_polygon((100,350),(250,250),(400,350),fill='yellow')
r=c.create_rectangle((220,290),(280,320),fill='green')
c.pack()
root.mainloop()

# %%
root=Tk()
root.geometry('600x600')
c=Canvas(root,bg='red',height=500,width=500)
r=c.create_rectangle((110,110),(400,400),fill='green')
c.pack()
root.mainloop()

# %%
root=Tk()
root.geometry('600x600')
c=Canvas(root,bg='red',height=500,width=500)
r=c.create_rectangle((110,110),(400,400),fill='green')
r=c.create_rectangle((210,210),(300,300),fill='blue')
rec=c.create_line(0,0,110,110,fill='black',width=3)
rec=c.create_line(0,500,110,400,fill='black',width=3)
rec=c.create_line(500,500,400,400,fill='black',width=3)
rec=c.create_line(500,0,400,110,fill='black',width=3)
c.pack()
root.mainloop()

# %%
root=Tk()
root.geometry('600x600')
c=Canvas(root,bg='red',height=500,width=500)
#r=c.create_arc(200,400,300,500,start=0,extent=200,fill='green')
r=c.create_arc(0, 340, 200, 100, width = 5, fill = "orange")
c.pack()
root.mainloop()

# %%
root=Tk()
root.geometry('600x600')
c=Canvas(root,bg='red',height=500,width=500)
c.create_oval(200, 100, 300, 250, width = 3,fill='orange')
c.pack()
root.mainloop()

# %%
root=Tk()
root.geometry('600x600')
c=Canvas(root,bg='red',height=500,width=500)
c.create_oval(200, 100, 300, 200, width = 3,fill='orange')
c.pack()
root.mainloop()

# %%
root=Tk()
root.geometry('600x600')
c=Canvas(root,bg='red',height=500,width=500)
r=c.create_arc(250,220,400,400,start=0,extent=5000,fill='green')
r=c.create_oval(350,200,300,300,width=2,fill='blue')
c.pack()
root.mainloop()
